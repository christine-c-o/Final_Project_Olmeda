# %%
import matplotlib.pyplot as plt
import sklearn
import os
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import warnings

from sklearn.cluster import KMeans

# %%
df=pd.read_csv("winequality-red.csv")

# %%
X=df.drop('quality',axis=1)

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %% [markdown]
# # Machine Learning using KMeans; Data is Scaled For Analysis

# %% [markdown]
# # KMeans Clusters=2

# %%
kmeans=KMeans(n_clusters=2)

kmeans.fit(X)

predicted_classes1=kmeans.predict(X)

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X)

X_train_scaled = X_scaler.transform(X)

kmeans.fit(X_train_scaled)

predicted_classes2=kmeans.predict(X_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans Clusters=3

# %%
kmeans=KMeans(n_clusters=3)

kmeans.fit(X)

predicted_classes1=kmeans.predict(X)

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X)

X_train_scaled = X_scaler.transform(X)

kmeans.fit(X_train_scaled)

predicted_classes2=kmeans.predict(X_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans Clusters=4

# %%
kmeans=KMeans(n_clusters=4)

kmeans.fit(X)

predicted_classes1=kmeans.predict(X)

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X)

X_train_scaled = X_scaler.transform(X)

kmeans.fit(X_train_scaled)

predicted_classes2=kmeans.predict(X_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans Clusters=5

# %%
kmeans=KMeans(n_clusters=5)

kmeans.fit(X)

predicted_classes1=kmeans.predict(X)

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X)

X_train_scaled = X_scaler.transform(X)

kmeans.fit(X_train_scaled)

predicted_classes2=kmeans.predict(X_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans Clusters=6

# %%
kmeans=KMeans(n_clusters=6)

kmeans.fit(X)

predicted_classes1=kmeans.predict(X)

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X)

X_train_scaled = X_scaler.transform(X)

kmeans.fit(X_train_scaled)

predicted_classes2=kmeans.predict(X_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans Clusters=8

# %%
kmeans=KMeans(n_clusters=8)

kmeans.fit(X)

predicted_classes1=kmeans.predict(X)

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X)

X_train_scaled = X_scaler.transform(X)

kmeans.fit(X_train_scaled)

predicted_classes2=kmeans.predict(X_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans Clusters=10

# %%
kmeans=KMeans(n_clusters=10)

kmeans.fit(X)

predicted_classes1=kmeans.predict(X)

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X)

X_train_scaled = X_scaler.transform(X)

kmeans.fit(X_train_scaled)

predicted_classes2=kmeans.predict(X_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans Clusters=12

# %%
kmeans=KMeans(n_clusters=12)

kmeans.fit(X)

predicted_classes1=kmeans.predict(X)

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X)

X_train_scaled = X_scaler.transform(X)

kmeans.fit(X_train_scaled)

predicted_classes2=kmeans.predict(X_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # In data exploration the Pearson Correlation Matrix showed the characteristics wtih the highest correlation to quality were  volatile acidity as a negative correlation and alcohol, sulphates, and citric acid as positive correlations.  The following dataframe explores Machine Learning only using those four columns.

# %%
Y=df.drop([ 'fixed acidity','residual sugar', 'chlorides', 'free sulfur dioxide',
           'total sulfur dioxide', 'density', 'pH', 'quality'],axis=1)

# %%
Y.head()
# Out:
#    volatile acidity  citric acid  sulphates  alcohol
# 0              0.70         0.00       0.56      9.4
# 1              0.88         0.00       0.68      9.8
# 2              0.76         0.04       0.65      9.8
# 3              0.28         0.56       0.58      9.8
# 4              0.70         0.00       0.56      9.4

# %% [markdown]
# # KMeans Clusters=2 (Highest Correlation Variables Only)

# %%
kmeans=KMeans(n_clusters=2)

kmeans.fit(Y)

predicted_classes1=kmeans.predict(Y)

from sklearn.preprocessing import StandardScaler

Y_scaler = StandardScaler().fit(Y)

Y_train_scaled = Y_scaler.transform(Y)

kmeans.fit(Y_train_scaled)

predicted_classes2=kmeans.predict(Y_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(Y_train_scaled[:, 0], Y_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans Clusters=3 (Highest Correlation Variables Only)

# %%
kmeans=KMeans(n_clusters=3)

kmeans.fit(Y)

predicted_classes1=kmeans.predict(Y)

from sklearn.preprocessing import StandardScaler

Y_scaler = StandardScaler().fit(Y)

Y_train_scaled = Y_scaler.transform(Y)

kmeans.fit(Y_train_scaled)

predicted_classes2=kmeans.predict(Y_train_scaled)

df_model=pd.DataFrame(
{
    'orig_label':df['quality'].values,
    'predicted':predicted_classes2
})

df_model['predicted'].value_counts(normalize=True)

df['quality'].value_counts(normalize=True)

plt.scatter(Y_train_scaled[:, 0], Y_train_scaled[:, 1], c=predicted_classes2, s=50, cmap='viridis')
plt.title('KMeans Trained and Scaled Scatter Plot')
plt.show()

# %%
plt.scatter(df_model['predicted'], df['quality'])
plt.ylabel('Wine Quality Category')
plt.xlabel('KMeans Prediction')
plt.title('Wine Quality Category vs. KMeans Prediction Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Wine Quality Category vs. KMeans Prediction Scatter Plot')

# %% [markdown]
# # KMeans with two clusters provided the best fit, however, there were high and low quality wines in both clusters.  Wine quality cannot be predicted based on the characteristics in this data set using KMeans. Another Machine Learning model may provide a better prediction.

# %% [markdown]
# # It is my opinion that wine quality is a personal preference so drink what you enjoy, not what is rated highly!
